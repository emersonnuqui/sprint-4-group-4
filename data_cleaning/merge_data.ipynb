# %%
import pandas as pd
import pickle

# %%
## unpack pkl
panlasang_pinoy_pkl = pickle.load(open('../data/clean_panlasang_pinoy.pkl', 'rb'))

# %%
kawaling_pinoy_pkl = pickle.load(open('../data/clean_kawaling_pinoy.pkl', 'rb'))

# %%
all_recipes = pd.concat([panlasang_pinoy_pkl, kawaling_pinoy_pkl])
all_recipes
# Out:
#                                                   food       course  \
# 0                                  Pinoy Chicken Sopas         Soup
# 1    Popcorn Chicken and Gravy KFC Style Secret Recipe  Main Course
# 2                  Idol Cheesedog Bread Roll and Bites       Snacks
# 3                    Perfect Chicken Adobo on a Budget  Main Course
# 4                              Creamy Mushroom Chicken  Main Course
# ..                                                 ...          ...
# 589                      Garlic Butter Fried Frog Legs         none
# 590                                     Tinolang Manok  Main Course
# 591                 Tilapia in Black Bean Garlic Sauce  Main Course
# 592                                         Pork Adobo  Main Course
# 593                                  Sinigang na Baboy  Main Course
#
#                                            ingredients  \
# 0    1 lb. rotisserie chicken shredded, 2 Knorr Chi...
# ...

# %%
all_recipes.to_pickle('../data/all_recipes.pkl')
all_recipes.to_csv('../data/all_recipes.csv')
