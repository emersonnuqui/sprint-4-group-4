# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import bs4
import pandas as pd
import numpy as np
import random
import requests
from lxml import etree
import time

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import ElementNotInteractableException
from time import sleep
from webdriver_manager.chrome import ChromeDriverManager

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())

urls = []
for page in range(1, 78):
    driver.get("https://panlasangpinoy.com/categories/recipes/page/"+str(page)+"/")
    recipe = driver.find_elements(By.XPATH, '//div[@class = "entry-content"]//a[@class="more-link"]')

    for _recipe in recipe:
        urls.append({"url":_recipe.get_attribute('href')})
driver.quit()
# Out:
# C:\Users\emers\AppData\Local\Temp\ipykernel_9864\748927606.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       3 urls = []
#       4 for page in range(1, 78):
# ----> 5     driver.get("https://panlasangpinoy.com/categories/recipes/page/"+str(page)+"/")
#       6     recipe = driver.find_elements(By.XPATH, '//div[@class = "entry-content"]//a[@class="more-link"]')
#       8     for _recipe in recipe:
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:442, in WebDriver.get(self, url)
#     438 def get(self, url: str) -> None:
#     439     """
#     440     Loads a web page in the current browser session.
#     441     """
# --> 442     self.execute(Command.GET, {'url': url})
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: unable to connect to renderer)
#   (Session info: chrome=107.0.5304.107)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00E0ACD3+2075859]
# 	Ordinal0 [0x00D9EE61+1633889]
# 	Ordinal0 [0x00C9B7BD+571325]
# 	Ordinal0 [0x00C8DDAD+515501]
# 	Ordinal0 [0x00CA185D+596061]
# 	Ordinal0 [0x00CFB93B+964923]
# 	Ordinal0 [0x00CE7136+880950]
# 	Ordinal0 [0x00CBFEFD+720637]
# 	Ordinal0 [0x00CC0F3F+724799]
# 	GetHandleVerifier [0x010BEED2+2769538]
# 	GetHandleVerifier [0x010B0D95+2711877]
# 	GetHandleVerifier [0x00E9A03A+521194]
# 	GetHandleVerifier [0x00E98DA0+516432]
# 	Ordinal0 [0x00DA682C+1665068]
# 	Ordinal0 [0x00DAB128+1683752]
# 	Ordinal0 [0x00DAB215+1683989]
# 	Ordinal0 [0x00DB6484+1729668]
# 	BaseThreadInitThunk [0x75226739+25]
# 	RtlGetFullPathName_UEx [0x76FD8FD2+1218]
# 	RtlGetFullPathName_UEx [0x76FD8F9D+1165]

# %%
data = pd.DataFrame(urls)

# %%
final_data = pd.read_csv("all_recipe_urls_panlasang_pinoy.csv")

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
recipes_1 = []

for food in final_data["urls"][:400]:
    driver.get(food)
    total_height = int(driver.execute_script("return document.body.scrollHeight"))
    for i in range(1, total_height, 5):
        driver.execute_script("window.scrollTo(0, {});".format(i))
    try:
        meal = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//h2[@class='wprm-recipe-name wprm-block-text-bold']").text
    except:
        meal = "none"
    try:
        course = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-course wprm-block-text-normal']").text
    except:
        course = 'none'
    #keyword = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-keyword wprm-block-text-normal']").text
    #prep_and_cook_time = driver.find_elements(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-time wprm-block-text-normal']")
    #cook_time = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-cook_time wprm-recipe-cook_time-minutes']").text
    #number_of_serving = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//a[@class='wprm-recipe-servings-link']").text
    #calories = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-calories wprm-block-text-normal']").text
    try:
        ingredients_list = driver.find_elements(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//li[@class='wprm-recipe-ingredient']")
        ingredients = []
        for i in range(0, len(ingredients_list)):
            ingredients.append(ingredients_list[i].text)
        ingredients = ', '.join(ingredients)
    except:
        ingredients = "none"
    try:
        instructions = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//ul[@class='wprm-recipe-instructions']").text
    except:
        instructions = 'none'
        
    
    recipes_1.append({
        "url": food,
        "food": meal,
        "course": course,
        #"keyword": keyword, 
        #"prep time": prep_and_cook_time[0].text,
        #"cook time": prep_and_cook_time[1].text,
        #"number of serving": number_of_serving, 
        #"calories": calories,
        "ingredients": ingredients,
        "instructions": instructions
        })
    time.sleep(1.5)
# Out:
# C:\Users\emers\AppData\Local\Temp\ipykernel_30004\1384213066.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
recipes_2 = []

for food in final_data["urls"][400:800]:
    driver.get(food)
    total_height = int(driver.execute_script("return document.body.scrollHeight"))
    for i in range(1, total_height, 5):
        driver.execute_script("window.scrollTo(0, {});".format(i))
    try:
        meal = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//h2[@class='wprm-recipe-name wprm-block-text-bold']").text
    except:
        meal = "none"
    try:
        course = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-course wprm-block-text-normal']").text
    except:
        course = 'none'
    #keyword = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-keyword wprm-block-text-normal']").text
    #prep_and_cook_time = driver.find_elements(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-time wprm-block-text-normal']")
    #cook_time = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-cook_time wprm-recipe-cook_time-minutes']").text
    #number_of_serving = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//a[@class='wprm-recipe-servings-link']").text
    #calories = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-calories wprm-block-text-normal']").text
    try:
        ingredients_list = driver.find_elements(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//li[@class='wprm-recipe-ingredient']")
        ingredients = []
        for i in range(0, len(ingredients_list)):
            ingredients.append(ingredients_list[i].text)
        ingredients = ', '.join(ingredients)
    except:
        ingredients = "none"
    try:
        instructions = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//ul[@class='wprm-recipe-instructions']").text
    except:
        instructions = 'none'
        
    
    recipes_2.append({
        "url": food,
        "food": meal,
        "course": course,
        #"keyword": keyword, 
        #"prep time": prep_and_cook_time[0].text,
        #"cook time": prep_and_cook_time[1].text,
        #"number of serving": number_of_serving, 
        #"calories": calories,
        "ingredients": ingredients,
        "instructions": instructions
        })
    time.sleep(1.5)
# Out:
# [WDM] - Downloading: 100%|██████████| 6.46M/6.46M [00:01<00:00, 4.65MB/s]
# C:\Users\emers\AppData\Local\Temp\ipykernel_30004\174557449.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
recipes_3 = []

for food in final_data["urls"][800:1200]:
    driver.get(food)
    total_height = int(driver.execute_script("return document.body.scrollHeight"))
    for i in range(1, total_height, 5):
        driver.execute_script("window.scrollTo(0, {});".format(i))
    try:
        meal = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//h2[@class='wprm-recipe-name wprm-block-text-bold']").text
    except:
        meal = "none"
    try:
        course = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-course wprm-block-text-normal']").text
    except:
        course = 'none'
    #keyword = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-keyword wprm-block-text-normal']").text
    #prep_and_cook_time = driver.find_elements(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-time wprm-block-text-normal']")
    #cook_time = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-cook_time wprm-recipe-cook_time-minutes']").text
    #number_of_serving = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//a[@class='wprm-recipe-servings-link']").text
    #calories = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-calories wprm-block-text-normal']").text
    try:
        ingredients_list = driver.find_elements(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//li[@class='wprm-recipe-ingredient']")
        ingredients = []
        for i in range(0, len(ingredients_list)):
            ingredients.append(ingredients_list[i].text)
        ingredients = ', '.join(ingredients)
    except:
        ingredients = "none"
    try:
        instructions = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//ul[@class='wprm-recipe-instructions']").text
    except:
        instructions = 'none'
        
    
    recipes_3.append({
        "url": food,
        "food": meal,
        "course": course,
        #"keyword": keyword, 
        #"prep time": prep_and_cook_time[0].text,
        #"cook time": prep_and_cook_time[1].text,
        #"number of serving": number_of_serving, 
        #"calories": calories,
        "ingredients": ingredients,
        "instructions": instructions
        })
    time.sleep(1.5)
# Out:
# C:\Users\emers\AppData\Local\Temp\ipykernel_30004\891651951.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
recipes_4 = []

for food in final_data["urls"][1200:1500]:
    driver.get(food)
    total_height = int(driver.execute_script("return document.body.scrollHeight"))
    for i in range(1, total_height, 5):
        driver.execute_script("window.scrollTo(0, {});".format(i))
    try:
        meal = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//h2[@class='wprm-recipe-name wprm-block-text-bold']").text
    except:
        meal = "none"
    try:
        course = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-course wprm-block-text-normal']").text
    except:
        course = 'none'
    #keyword = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-keyword wprm-block-text-normal']").text
    #prep_and_cook_time = driver.find_elements(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-time wprm-block-text-normal']")
    #cook_time = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-cook_time wprm-recipe-cook_time-minutes']").text
    #number_of_serving = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//a[@class='wprm-recipe-servings-link']").text
    #calories = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-calories wprm-block-text-normal']").text
    try:
        ingredients_list = driver.find_elements(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//li[@class='wprm-recipe-ingredient']")
        ingredients = []
        for i in range(0, len(ingredients_list)):
            ingredients.append(ingredients_list[i].text)
        ingredients = ', '.join(ingredients)
    except:
        ingredients = "none"
    try:
        instructions = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//ul[@class='wprm-recipe-instructions']").text
    except:
        instructions = 'none'
        
    
    recipes_4.append({
        "url": food,
        "food": meal,
        "course": course,
        #"keyword": keyword, 
        #"prep time": prep_and_cook_time[0].text,
        #"cook time": prep_and_cook_time[1].text,
        #"number of serving": number_of_serving, 
        #"calories": calories,
        "ingredients": ingredients,
        "instructions": instructions
        })
    time.sleep(1.5)

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
recipes_5 = []

for food in final_data["urls"][1500:]:
    driver.get(food)
    total_height = int(driver.execute_script("return document.body.scrollHeight"))
    for i in range(1, total_height, 5):
        driver.execute_script("window.scrollTo(0, {});".format(i))
    try:
        meal = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//h2[@class='wprm-recipe-name wprm-block-text-bold']").text
    except:
        meal = "none"
    try:
        course = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-course wprm-block-text-normal']").text
    except:
        course = 'none'
    #keyword = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-keyword wprm-block-text-normal']").text
    #prep_and_cook_time = driver.find_elements(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-time wprm-block-text-normal']")
    #cook_time = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-details wprm-recipe-details-minutes wprm-recipe-cook_time wprm-recipe-cook_time-minutes']").text
    #number_of_serving = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//a[@class='wprm-recipe-servings-link']").text
    #calories = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//span[@class='wprm-recipe-details wprm-recipe-nutrition wprm-recipe-calories wprm-block-text-normal']").text
    try:
        ingredients_list = driver.find_elements(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//li[@class='wprm-recipe-ingredient']")
        ingredients = []
        for i in range(0, len(ingredients_list)):
            ingredients.append(ingredients_list[i].text)
        ingredients = ', '.join(ingredients)
    except:
        ingredients = "none"
    try:
        instructions = driver.find_element(By.XPATH,"//div[@class='wprm-recipe wprm-recipe-template-classic']//ul[@class='wprm-recipe-instructions']").text
    except:
        instructions = 'none'
        
    
    recipes_5.append({
        "url": food,
        "food": meal,
        "course": course,
        #"keyword": keyword, 
        #"prep time": prep_and_cook_time[0].text,
        #"cook time": prep_and_cook_time[1].text,
        #"number of serving": number_of_serving, 
        #"calories": calories,
        "ingredients": ingredients,
        "instructions": instructions
        })
    time.sleep(1.5)
# Out:
#                                 food  \
# 0                    Spinach Lasagne
# 1                Smoked Salmon Pasta
# 2           Chicken Guisantes Recipe
# 3    Kalderetang Kambing (Goat Stew)
# 4                     Steamed Shrimp
# ..                               ...
# 271              Tartar Sauce Recipe
# 272       Hoisin Glazed Grilled Tofu
# 273  Grilled Ribs with Pico de Gallo
# 274                 Grilled Calamari
# 275             Curried Potato Salad
#
#                                            ingredients  \
# 0    1 9 oz. box, oven ready lasagne, 1 1/2 lb. gro...
# 1    1 lb. spaghetti noodles, 2 ½ cups Alfredo sauc...
# 2    2 lbs. chicken thigh cut into serving pieces, ...
# 3    3 lbs. goat meat chevon, chopped, 2 cups butte...
# 4    2 lbs. medium shrimp, 1 1/2 tablespoons coarse...
# ..                                                 ...
# 271  3/4 cup mayonnaise, 2 teaspoons yellow onion f...
# 272  14 oz. extra firm tofu sliced into 1/2 inch th...
# 273  2 lbs. spare ribs, 3/4 cups dark soy sauce, Ju...
# 274  2 lbs. small to medium squid cleaned, 1/4 cup ...
# 275  1 lb. red potatoes, 1/2 cup mayonnaise, 2 tabl...
#
#                                           instructions
# 0    Prepare the meat sauce by heating the oil in a...
# 1    Cook the spaghetti noodles according to packag...
# 2    Heat the cooking oil in a cooking pot.\nSaute ...
# 3    Soak the goat meat in buttermilk overnight. Wa...
# 4    Sprinkle salt, garlic powder, and ground black...
# ..                                                 ...
# 271  Combine mayonnaise and lemon juice in a bowl. ...
# 272  Combine hoisin sauce, salt, and pepper. Mix we...
# 273  Combine the soy sauce, lemon juice, garlic pow...
# 274  Combine soy sauce, Sriracha sauce, sugar, lemo...
# 275  Pour water on a cooking pot. Let boil.\nAdd th...
#
# [276 rows x 3 columns]

# %%
data1 = pd.DataFrame(recipes_1)
data2 = pd.DataFrame(recipes_2)
data3 = pd.DataFrame(recipes_3)

# %%
data1.to_csv("panlasang_pinoy_1.csv", index=False)
data2.to_csv("panlasang_pinoy_2.csv", index=False)
data3.to_csv("panlasang_pinoy_3.csv", index=False)

# %%
panlasa1 = pd.read_csv("panlasang_pinoy_1.csv")
panlasa2 = pd.read_csv("panlasang_pinoy_2.csv")
panlasa3 = pd.read_csv("panlasang_pinoy_3.csv")
panlasa4 = pd.read_csv("panlasang_pinoy_4.csv")
panlasa5 = pd.read_csv("panlasang_pinoy_5.csv")

# %%
final_data = pd.concat([panlasa1, panlasa2, panlasa3, panlasa4, panlasa5])

# %%
final_data.to_csv("panlasang_pinoy.csv", index=False)
